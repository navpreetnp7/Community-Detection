# %%
import time
import argparse
import numpy as np

import torch
import torch.optim as optim

from utils import load_data,normalize,toy_data,nmi_score,modularity_matrix,modularity
from models import GNN

import community as community_louvain
from networkx import from_numpy_matrix
import networkx as nx

from sklearn.cluster import SpectralClustering

import pycombo

import pandas as pd

torch.set_printoptions(sci_mode=False)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
cuda = torch.cuda.is_available()
weight_decay = 10e-10
epochs = 1000
seed = 165

# %%
np.random.seed(seed)
torch.manual_seed(seed)
if cuda:
    torch.cuda.manual_seed(seed)

# %%
def community_detection(G,method,features=None):
    
    adj = nx.to_numpy_matrix(G)
    adj = np.expand_dims(adj, axis=0)
    
    #Combo
    combo_partition = pycombo.execute(G)
    nb_comm = max(combo_partition[0].values())+1
    combo_mod = combo_partition[1]

    adj_norm = normalize(adj)

    adj = torch.FloatTensor(np.array(adj))
    adj_norm = torch.FloatTensor(np.array(adj_norm))
    
    if type(features) == type(None):
        
        # features
        if method == "louvain":
            partition = community_louvain.best_partition(G)
            #get binary matrix of the partition
            nb_community = max(list(partition.values())) + 1
            communities =  np.array(list(partition.values())).reshape(-1)
            C = np.eye(nb_community)[communities]
            C = torch.FloatTensor(C)
            #perturbations
            C = perturb(C)
        elif method == "spectral":
            partition = spectralPartition(adj,nb_comm)
            C = partition.float()
            nb_community = C.shape[1]
    
        features = torch.FloatTensor(C)
        features = features.unsqueeze(0)
        C = torch.FloatTensor(C).unsqueeze(0)
    
    if method == "louvain":
        lr = 0.001
    elif method == "spectral":
        lr = 0.001
    
    nb_community = features.shape[-1]

    Q = modularity_matrix(adj)
    
    # Model and optimizer

    model = GNN(batch_size=adj.shape[0],
                nfeat=adj.shape[1],
                ndim=nb_community)

    if cuda:
        model.cuda()
        features = features.cuda()
        adj = adj.cuda()
        adj_norm = adj_norm.cuda()
        Q = Q.cuda()
        #C = C.cuda()

    # Train model
    t_total = time.time()

    optimizer = optim.Adam(model.parameters(),
                           lr=lr, weight_decay=weight_decay)
    
    #print(features)
    for epoch in range(epochs):

        t = time.time()
        model.train()
        optimizer.zero_grad()

        C = model(features, adj_norm)
        loss = modularity(C,Q)

        loss.backward(retain_graph=True)

        optimizer.step()

        if epoch == 0:
            best_loss = loss
            init_mod = loss
            best_C = C
        else:
            if loss < best_loss:
                best_loss = loss
                best_C = C

        if epoch % 100 == 0:
            print('Epoch: {:04d}'.format(epoch + 1),
                  'Modularity: {:.8f}'.format(-best_loss.item()),
                  'time: {:.4f}s'.format(time.time() - t))

    print("Optimization Finished!")
    print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
    
    #print(best_C)
     
    return nb_community,-init_mod,-best_loss,combo_mod,best_C

# %%
def perturb(A):
    p = 0.4
    epsilon = torch.rand(A.shape).uniform_(0, p) - torch.rand(A.shape).uniform_(0, p)
    return torch.clip(A + epsilon,0,1)

# %%
def spectralPartition(A,nb_comm):
    A = A[0] # TODO 3D
    clustering = SpectralClustering(n_clusters=nb_comm,assign_labels='discretize',random_state=0).fit(A)
    clusters = list(clustering.labels_)
    partitions = torch.tensor(clusters)
    return torch.nn.functional.one_hot(partitions)

# %%
G = [nx.karate_club_graph(),nx.les_miserables_graph(),nx.florentine_families_graph(),nx.house_graph()]
methods = ["louvain","spectral"]
nb_communities = []
init_mods = []
finetuned_mods = []
combo_mods = []
methodss = []
networks = ["Karate Club","Karate Club","Les Miserables","Les Miserables","Florentine","Florentine","House Graph","House Graph"]
for network in G:
    for method in methods:
        print(network,end=" ")
        print(method)
        nb_community,init_mod,finetuned_mod,combo_mod,features = community_detection(network,method)
        initial_mod = torch.clone(init_mod)
        while(init_mod<finetuned_mod):
            nb_community,init_mod,finetuned_mod,combo_mod,features = community_detection(network,method,features)
        nb_communities.append(nb_community)
        init_mods.append(initial_mod.cpu().detach().numpy()[0][0])
        finetuned_mods.append(finetuned_mod.cpu().detach().numpy()[0][0])
        combo_mods.append(combo_mod)
        methodss.append(method)
# Out:
# Zachary's Karate Club louvain
# Epoch: 0001 Modularity: 0.23050189 time: 0.3561s
# Epoch: 0101 Modularity: 0.41559827 time: 0.0010s
# Epoch: 0201 Modularity: 0.41559827 time: 0.0010s
# Epoch: 0301 Modularity: 0.41559827 time: 0.0010s
# Epoch: 0401 Modularity: 0.41559827 time: 0.0010s
# Epoch: 0501 Modularity: 0.41559827 time: 0.0010s
# Epoch: 0601 Modularity: 0.41559827 time: 0.0010s
# Epoch: 0701 Modularity: 0.41559827 time: 0.0010s
# Epoch: 0801 Modularity: 0.41559827 time: 0.0010s
# Epoch: 0901 Modularity: 0.41559827 time: 0.0010s
# Optimization Finished!
# Total time elapsed: 1.3106s
# Epoch: 0001 Modularity: 0.41559827 time: 0.0010s
# Epoch: 0101 Modularity: 0.41724196 time: 0.0020s
# Epoch: 0201 Modularity: 0.41724196 time: 0.0010s
# Epoch: 0301 Modularity: 0.41724196 time: 0.0020s
# Epoch: 0401 Modularity: 0.41724196 time: 0.0010s
# Epoch: 0501 Modularity: 0.41724196 time: 0.0010s
# Epoch: 0601 Modularity: 0.41724196 time: 0.0010s
# Epoch: 0701 Modularity: 0.41724196 time: 0.0010s
# Epoch: 0801 Modularity: 0.41724196 time: 0.0010s
# Epoch: 0901 Modularity: 0.41724196 time: 0.0021s
# Optimization Finished!
# Total time elapsed: 1.2544s
# Epoch: 0001 Modularity: 0.41724196 time: 0.0010s
# Epoch: 0101 Modularity: 0.41937870 time: 0.0010s
# Epoch: 0201 Modularity: 0.41937870 time: 0.0020s
# Epoch: 0301 Modularity: 0.41937870 time: 0.0010s
# Epoch: 0401 Modularity: 0.41937870 time: 0.0010s
# Epoch: 0501 Modularity: 0.41937870 time: 0.0020s
# Epoch: 0601 Modularity: 0.41937870 time: 0.0020s
# Epoch: 0701 Modularity: 0.41937870 time: 0.0020s
# Epoch: 0801 Modularity: 0.41937870 time: 0.0010s
# Epoch: 0901 Modularity: 0.41937870 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 1.4181s
# Epoch: 0001 Modularity: 0.41937870 time: 0.0020s
# Epoch: 0101 Modularity: 0.41978961 time: 0.0020s
# Epoch: 0201 Modularity: 0.41978961 time: 0.0020s
# Epoch: 0301 Modularity: 0.41978961 time: 0.0010s
# Epoch: 0401 Modularity: 0.41978961 time: 0.0020s
# Epoch: 0501 Modularity: 0.41978961 time: 0.0010s
# Epoch: 0601 Modularity: 0.41978961 time: 0.0020s
# Epoch: 0701 Modularity: 0.41978961 time: 0.0010s
# Epoch: 0801 Modularity: 0.41978961 time: 0.0030s
# Epoch: 0901 Modularity: 0.41978961 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 1.5994s
# Epoch: 0001 Modularity: 0.41978961 time: 0.0020s
# Epoch: 0101 Modularity: 0.41978961 time: 0.0020s
# Epoch: 0201 Modularity: 0.41978961 time: 0.0020s
# Epoch: 0301 Modularity: 0.41978961 time: 0.0020s
# Epoch: 0401 Modularity: 0.41978961 time: 0.0020s
# Epoch: 0501 Modularity: 0.41978961 time: 0.0020s
# Epoch: 0601 Modularity: 0.41978961 time: 0.0020s
# Epoch: 0701 Modularity: 0.41978961 time: 0.0020s
# Epoch: 0801 Modularity: 0.41978961 time: 0.0020s
# Epoch: 0901 Modularity: 0.41978961 time: 0.0010s
# Optimization Finished!
# Total time elapsed: 1.8596s
# Zachary's Karate Club spectral
# Epoch: 0001 Modularity: 0.34015450 time: 0.0010s
# Epoch: 0101 Modularity: 0.36309701 time: 0.0010s
# Epoch: 0201 Modularity: 0.36985219 time: 0.0010s
# Epoch: 0301 Modularity: 0.37284279 time: 0.0010s
# Epoch: 0401 Modularity: 0.37287143 time: 0.0010s
# Epoch: 0501 Modularity: 0.37290043 time: 0.0010s
# Epoch: 0601 Modularity: 0.37292910 time: 0.0010s
# Epoch: 0701 Modularity: 0.37295681 time: 0.0010s
# Epoch: 0801 Modularity: 0.37298191 time: 0.0010s
# Epoch: 0901 Modularity: 0.37300721 time: 0.0010s
# Optimization Finished!
# Total time elapsed: 0.9914s
# Epoch: 0001 Modularity: 0.37303090 time: 0.0020s
# Epoch: 0101 Modularity: 0.38069835 time: 0.0010s
# Epoch: 0201 Modularity: 0.40174022 time: 0.0010s
# Epoch: 0301 Modularity: 0.40203816 time: 0.0010s
# Epoch: 0401 Modularity: 0.40203816 time: 0.0010s
# Epoch: 0501 Modularity: 0.40203816 time: 0.0010s
# Epoch: 0601 Modularity: 0.40203816 time: 0.0010s
# Epoch: 0701 Modularity: 0.40203816 time: 0.0010s
# Epoch: 0801 Modularity: 0.40203816 time: 0.0020s
# Epoch: 0901 Modularity: 0.40203816 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 1.2716s
# Epoch: 0001 Modularity: 0.40203816 time: 0.0010s
# Epoch: 0101 Modularity: 0.40203816 time: 0.0020s
# Epoch: 0201 Modularity: 0.40203816 time: 0.0020s
# Epoch: 0301 Modularity: 0.40203816 time: 0.0010s
# Epoch: 0401 Modularity: 0.40203816 time: 0.0020s
# Epoch: 0501 Modularity: 0.40203816 time: 0.0020s
# Epoch: 0601 Modularity: 0.40203816 time: 0.0020s
# Epoch: 0701 Modularity: 0.40203816 time: 0.0010s
# Epoch: 0801 Modularity: 0.40203816 time: 0.0020s
# Epoch: 0901 Modularity: 0.40203816 time: 0.0010s
# Optimization Finished!
# Total time elapsed: 1.4614s
#  louvain
# Epoch: 0001 Modularity: 0.27334279 time: 0.0010s
# Epoch: 0101 Modularity: 0.56541568 time: 0.0010s
# Epoch: 0201 Modularity: 0.56541568 time: 0.0010s
# Epoch: 0301 Modularity: 0.56541568 time: 0.0010s
# Epoch: 0401 Modularity: 0.56541568 time: 0.0010s
# Epoch: 0501 Modularity: 0.56541568 time: 0.0020s
# Epoch: 0601 Modularity: 0.56541568 time: 0.0010s
# Epoch: 0701 Modularity: 0.56541568 time: 0.0010s
# Epoch: 0801 Modularity: 0.56541568 time: 0.0010s
# Epoch: 0901 Modularity: 0.56541568 time: 0.0010s
# Optimization Finished!
# Total time elapsed: 0.9625s
# Epoch: 0001 Modularity: 0.56541568 time: 0.0010s
# Epoch: 0101 Modularity: 0.56582165 time: 0.0010s
# Epoch: 0201 Modularity: 0.56582165 time: 0.0020s
# Epoch: 0301 Modularity: 0.56582165 time: 0.0010s
# Epoch: 0401 Modularity: 0.56582165 time: 0.0010s
# Epoch: 0501 Modularity: 0.56582165 time: 0.0010s
# Epoch: 0601 Modularity: 0.56582165 time: 0.0010s
# Epoch: 0701 Modularity: 0.56582165 time: 0.0010s
# Epoch: 0801 Modularity: 0.56582165 time: 0.0020s
# Epoch: 0901 Modularity: 0.56582165 time: 0.0010s
# Optimization Finished!
# Total time elapsed: 1.2075s
# Epoch: 0001 Modularity: 0.56582165 time: 0.0010s
# Epoch: 0101 Modularity: 0.56582165 time: 0.0010s
# Epoch: 0201 Modularity: 0.56582165 time: 0.0020s
# Epoch: 0301 Modularity: 0.56582165 time: 0.0010s
# Epoch: 0401 Modularity: 0.56582165 time: 0.0020s
# Epoch: 0501 Modularity: 0.56582165 time: 0.0010s
# Epoch: 0601 Modularity: 0.56582165 time: 0.0020s
# Epoch: 0701 Modularity: 0.56582165 time: 0.0010s
# Epoch: 0801 Modularity: 0.56582165 time: 0.0010s
# Epoch: 0901 Modularity: 0.56582165 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 1.4032s
#  spectral
# Epoch: 0001 Modularity: 0.11745612 time: 0.0010s
# Epoch: 0101 Modularity: 0.30394089 time: 0.0010s
# Epoch: 0201 Modularity: 0.31548297 time: 0.0010s
# Epoch: 0301 Modularity: 0.31768671 time: 0.0010s
# Epoch: 0401 Modularity: 0.32656363 time: 0.0010s
# Epoch: 0501 Modularity: 0.32677537 time: 0.0010s
# Epoch: 0601 Modularity: 0.32686335 time: 0.0010s
# Epoch: 0701 Modularity: 0.32687178 time: 0.0010s
# Epoch: 0801 Modularity: 0.32687229 time: 0.0010s
# Epoch: 0901 Modularity: 0.32687259 time: 0.0010s
# Optimization Finished!
# Total time elapsed: 0.9385s
# Epoch: 0001 Modularity: 0.34061691 time: 0.0020s
# Epoch: 0101 Modularity: 0.48699775 time: 0.0020s
# Epoch: 0201 Modularity: 0.48907566 time: 0.0010s
# Epoch: 0301 Modularity: 0.49191278 time: 0.0010s
# Epoch: 0401 Modularity: 0.49496025 time: 0.0010s
# Epoch: 0501 Modularity: 0.49496657 time: 0.0010s
# Epoch: 0601 Modularity: 0.49496657 time: 0.0010s
# Epoch: 0701 Modularity: 0.49496657 time: 0.0010s
# Epoch: 0801 Modularity: 0.49496657 time: 0.0010s
# Epoch: 0901 Modularity: 0.49496657 time: 0.0010s
# Optimization Finished!
# Total time elapsed: 1.1485s
# Epoch: 0001 Modularity: 0.49496657 time: 0.0020s
# Epoch: 0101 Modularity: 0.50868005 time: 0.0020s
# Epoch: 0201 Modularity: 0.50868005 time: 0.0010s
# Epoch: 0301 Modularity: 0.50868005 time: 0.0020s
# Epoch: 0401 Modularity: 0.50868005 time: 0.0010s
# Epoch: 0501 Modularity: 0.50868005 time: 0.0010s
# Epoch: 0601 Modularity: 0.50868005 time: 0.0020s
# Epoch: 0701 Modularity: 0.50868005 time: 0.0010s
# Epoch: 0801 Modularity: 0.50868005 time: 0.0020s
# Epoch: 0901 Modularity: 0.50868005 time: 0.0010s
# Optimization Finished!
# Total time elapsed: 1.4041s
# Epoch: 0001 Modularity: 0.50868005 time: 0.0020s
# Epoch: 0101 Modularity: 0.51882821 time: 0.0020s
# Epoch: 0201 Modularity: 0.51882827 time: 0.0020s
# Epoch: 0301 Modularity: 0.51882827 time: 0.0010s
# Epoch: 0401 Modularity: 0.51882827 time: 0.0020s
# Epoch: 0501 Modularity: 0.51882827 time: 0.0020s
# Epoch: 0601 Modularity: 0.51882827 time: 0.0020s
# Epoch: 0701 Modularity: 0.51882827 time: 0.0010s
# Epoch: 0801 Modularity: 0.51882827 time: 0.0010s
# Epoch: 0901 Modularity: 0.51882827 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 1.5609s
# Epoch: 0001 Modularity: 0.51882827 time: 0.0020s
# Epoch: 0101 Modularity: 0.51965111 time: 0.0020s
# Epoch: 0201 Modularity: 0.51980138 time: 0.0020s
# Epoch: 0301 Modularity: 0.51980138 time: 0.0020s
# Epoch: 0401 Modularity: 0.51980138 time: 0.0010s
# Epoch: 0501 Modularity: 0.51980138 time: 0.0020s
# Epoch: 0601 Modularity: 0.51980138 time: 0.0020s
# Epoch: 0701 Modularity: 0.51980138 time: 0.0010s
# Epoch: 0801 Modularity: 0.51980138 time: 0.0020s
# Epoch: 0901 Modularity: 0.51980138 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 1.7643s
# Epoch: 0001 Modularity: 0.51980138 time: 0.0030s
# Epoch: 0101 Modularity: 0.51980138 time: 0.0020s
# Epoch: 0201 Modularity: 0.51980138 time: 0.0020s
# Epoch: 0301 Modularity: 0.51980138 time: 0.0020s
# Epoch: 0401 Modularity: 0.51980138 time: 0.0020s
# Epoch: 0501 Modularity: 0.51980138 time: 0.0020s
# Epoch: 0601 Modularity: 0.51980138 time: 0.0020s
# Epoch: 0701 Modularity: 0.51980138 time: 0.0020s
# Epoch: 0801 Modularity: 0.51980138 time: 0.0020s
# Epoch: 0901 Modularity: 0.51980138 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 1.9831s
#  louvain
# Epoch: 0001 Modularity: 0.27652460 time: 0.0010s
# Epoch: 0101 Modularity: 0.39875001 time: 0.0010s
# Epoch: 0201 Modularity: 0.39875001 time: 0.0010s
# Epoch: 0301 Modularity: 0.39875001 time: 0.0010s
# Epoch: 0401 Modularity: 0.39875001 time: 0.0010s
# Epoch: 0501 Modularity: 0.39875001 time: 0.0010s
# Epoch: 0601 Modularity: 0.39875001 time: 0.0010s
# Epoch: 0701 Modularity: 0.39875001 time: 0.0010s
# Epoch: 0801 Modularity: 0.39875001 time: 0.0010s
# Epoch: 0901 Modularity: 0.39875001 time: 0.0010s
# Optimization Finished!
# Total time elapsed: 0.8976s
# Epoch: 0001 Modularity: 0.39875001 time: 0.0020s
# Epoch: 0101 Modularity: 0.39875001 time: 0.0010s
# Epoch: 0201 Modularity: 0.39875001 time: 0.0010s
# Epoch: 0301 Modularity: 0.39875001 time: 0.0010s
# Epoch: 0401 Modularity: 0.39875001 time: 0.0010s
# Epoch: 0501 Modularity: 0.39875001 time: 0.0020s
# Epoch: 0601 Modularity: 0.39875001 time: 0.0010s
# Epoch: 0701 Modularity: 0.39875001 time: 0.0010s
# Epoch: 0801 Modularity: 0.39875001 time: 0.0020s
# Epoch: 0901 Modularity: 0.39875001 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 1.1175s
#  spectral
# Epoch: 0001 Modularity: -0.17124999 time: 0.0010s
# Epoch: 0101 Modularity: 0.11084846 time: 0.0010s
# Epoch: 0201 Modularity: 0.12905133 time: 0.0010s
# Epoch: 0301 Modularity: 0.13573942 time: 0.0010s
# Epoch: 0401 Modularity: 0.14169256 time: 0.0010s
# Epoch: 0501 Modularity: 0.14800130 time: 0.0010s
# Epoch: 0601 Modularity: 0.14914866 time: 0.0010s
# Epoch: 0701 Modularity: 0.14966306 time: 0.0010s
# Epoch: 0801 Modularity: 0.14975972 time: 0.0010s
# Epoch: 0901 Modularity: 0.14976546 time: 0.0010s
# Optimization Finished!
# Total time elapsed: 0.8976s
# Epoch: 0001 Modularity: 0.14976564 time: 0.0010s
# Epoch: 0101 Modularity: 0.30526161 time: 0.0020s
# Epoch: 0201 Modularity: 0.30555558 time: 0.0010s
# Epoch: 0301 Modularity: 0.30555558 time: 0.0020s
# Epoch: 0401 Modularity: 0.30555558 time: 0.0010s
# Epoch: 0501 Modularity: 0.30555558 time: 0.0010s
# Epoch: 0601 Modularity: 0.30555558 time: 0.0010s
# Epoch: 0701 Modularity: 0.30555558 time: 0.0010s
# Epoch: 0801 Modularity: 0.30555558 time: 0.0010s
# Epoch: 0901 Modularity: 0.30555558 time: 0.0010s
# Optimization Finished!
# Total time elapsed: 1.1090s
# Epoch: 0001 Modularity: 0.30555558 time: 0.0010s
# Epoch: 0101 Modularity: 0.31625000 time: 0.0010s
# Epoch: 0201 Modularity: 0.31625003 time: 0.0020s
# Epoch: 0301 Modularity: 0.31625003 time: 0.0010s
# Epoch: 0401 Modularity: 0.31625003 time: 0.0010s
# Epoch: 0501 Modularity: 0.31625003 time: 0.0010s
# Epoch: 0601 Modularity: 0.31625003 time: 0.0010s
# Epoch: 0701 Modularity: 0.31625003 time: 0.0010s
# Epoch: 0801 Modularity: 0.31625003 time: 0.0020s
# Epoch: 0901 Modularity: 0.31625003 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 1.3474s
# Epoch: 0001 Modularity: 0.31625003 time: 0.0020s
# Epoch: 0101 Modularity: 0.31625003 time: 0.0020s
# Epoch: 0201 Modularity: 0.31625003 time: 0.0010s
# Epoch: 0301 Modularity: 0.31625003 time: 0.0010s
# Epoch: 0401 Modularity: 0.31625003 time: 0.0010s
# Epoch: 0501 Modularity: 0.31625003 time: 0.0020s
# Epoch: 0601 Modularity: 0.31625003 time: 0.0020s
# Epoch: 0701 Modularity: 0.31625003 time: 0.0020s
# Epoch: 0801 Modularity: 0.31625003 time: 0.0020s
# Epoch: 0901 Modularity: 0.31625003 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 1.5748s
# House Graph louvain
# Epoch: 0001 Modularity: 0.06814727 time: 0.0010s
# Epoch: 0101 Modularity: 0.11111113 time: 0.0010s
# Epoch: 0201 Modularity: 0.11111113 time: 0.0010s
# Epoch: 0301 Modularity: 0.11111113 time: 0.0010s
# Epoch: 0401 Modularity: 0.11111113 time: 0.0010s
# Epoch: 0501 Modularity: 0.11111113 time: 0.0010s
# Epoch: 0601 Modularity: 0.11111113 time: 0.0010s
# Epoch: 0701 Modularity: 0.11111113 time: 0.0010s
# Epoch: 0801 Modularity: 0.11111113 time: 0.0010s
# Epoch: 0901 Modularity: 0.11111113 time: 0.0010s
# Optimization Finished!
# Total time elapsed: 0.9835s
# Epoch: 0001 Modularity: 0.11111113 time: 0.0010s
# Epoch: 0101 Modularity: 0.11111113 time: 0.0020s
# Epoch: 0201 Modularity: 0.11111113 time: 0.0010s
# Epoch: 0301 Modularity: 0.11111113 time: 0.0010s
# Epoch: 0401 Modularity: 0.11111113 time: 0.0010s
# Epoch: 0501 Modularity: 0.11111113 time: 0.0010s
# Epoch: 0601 Modularity: 0.11111113 time: 0.0010s
# Epoch: 0701 Modularity: 0.11111113 time: 0.0010s
# Epoch: 0801 Modularity: 0.11111113 time: 0.0010s
# Epoch: 0901 Modularity: 0.11111113 time: 0.0010s
# Optimization Finished!
# Total time elapsed: 1.1649s
# House Graph spectral
# Epoch: 0001 Modularity: -0.34722221 time: 0.0010s
# Epoch: 0101 Modularity: -0.07360268 time: 0.0010s
# Epoch: 0201 Modularity: -0.02690880 time: 0.0010s
# Epoch: 0301 Modularity: -0.01155785 time: 0.0010s
# Epoch: 0401 Modularity: -0.00528445 time: 0.0010s
# Epoch: 0501 Modularity: -0.00246633 time: 0.0010s
# Epoch: 0601 Modularity: -0.00142223 time: 0.0000s
# Epoch: 0701 Modularity: -0.00096005 time: 0.0010s
# Epoch: 0801 Modularity: -0.00064218 time: 0.0000s
# Epoch: 0901 Modularity: -0.00042505 time: 0.0010s
# Optimization Finished!
# Total time elapsed: 0.8886s
# Epoch: 0001 Modularity: -0.00027910 time: 0.0010s
# Epoch: 0101 Modularity: -0.00004960 time: 0.0010s
# Epoch: 0201 Modularity: -0.00000474 time: 0.0010s
# Epoch: 0301 Modularity: 0.00000001 time: 0.0010s
# Epoch: 0401 Modularity: 0.00000031 time: 0.0010s
# Epoch: 0501 Modularity: 0.00002992 time: 0.0010s
# Epoch: 0601 Modularity: 0.04723703 time: 0.0010s
# Epoch: 0701 Modularity: 0.04723703 time: 0.0010s
# Epoch: 0801 Modularity: 0.04723703 time: 0.0010s
# Epoch: 0901 Modularity: 0.04723703 time: 0.0010s
# Optimization Finished!
# Total time elapsed: 1.0911s
# Epoch: 0001 Modularity: 0.04723702 time: 0.0020s
# Epoch: 0101 Modularity: 0.11111113 time: 0.0010s
# Epoch: 0201 Modularity: 0.11111113 time: 0.0020s
# Epoch: 0301 Modularity: 0.11111113 time: 0.0010s
# Epoch: 0401 Modularity: 0.11111113 time: 0.0020s
# Epoch: 0501 Modularity: 0.11111113 time: 0.0010s
# Epoch: 0601 Modularity: 0.11111113 time: 0.0010s
# Epoch: 0701 Modularity: 0.11111113 time: 0.0010s
# Epoch: 0801 Modularity: 0.11111113 time: 0.0020s
# Epoch: 0901 Modularity: 0.11111113 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 1.3544s
# Epoch: 0001 Modularity: 0.11111113 time: 0.0020s
# Epoch: 0101 Modularity: 0.11111113 time: 0.0020s
# Epoch: 0201 Modularity: 0.11111113 time: 0.0010s
# Epoch: 0301 Modularity: 0.11111113 time: 0.0020s
# Epoch: 0401 Modularity: 0.11111113 time: 0.0020s
# Epoch: 0501 Modularity: 0.11111113 time: 0.0010s
# Epoch: 0601 Modularity: 0.11111113 time: 0.0020s
# Epoch: 0701 Modularity: 0.11111113 time: 0.0020s
# Epoch: 0801 Modularity: 0.11111113 time: 0.0010s
# Epoch: 0901 Modularity: 0.11111113 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 1.5608s

# %%
df = pd.DataFrame([networks,methodss,nb_communities,init_mods,finetuned_mods,combo_mods]).transpose()

# %%
df.columns = ["Network","Method","Communities","Initial Modularity","Finetuned Moduclarity","Combo Modularity"]

# %%
df
# Out:
#           Network    Method Communities Initial Modularity  \
# 0     Karate Club   louvain           4           0.230502
# 1     Karate Club  spectral           4           0.340154
# 2  Les Miserables   louvain           6           0.273343
# 3  Les Miserables  spectral           6           0.117456
# 4      Florentine   louvain           3           0.276525
# 5      Florentine  spectral           3          -0.171250
# 6     House Graph   louvain           2           0.068147
# 7     House Graph  spectral           2          -0.347222
#
#   Finetuned Moduclarity Combo Modularity
# 0              0.419790         0.419790
# 1              0.402038         0.419790
# 2              0.565822         0.566688
# 3              0.519801         0.566688
# 4              0.398750         0.398750
# 5              0.316250         0.398750
# 6              0.111111         0.111111
# 7              0.111111         0.111111
