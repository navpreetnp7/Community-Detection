# %%
import time
import argparse
import numpy as np

import torch
import torch.optim as optim

from utils import load_data,normalize,toy_data,nmi_score,modularity_matrix,modularity
from models import GNN

import community as community_louvain
from networkx import from_numpy_matrix
import networkx as nx

from sklearn.cluster import SpectralClustering

import pycombo

import pandas as pd

torch.set_printoptions(sci_mode=False)

import torch.nn as nn
from torch.nn.parameter import Parameter
from torch.nn.modules.module import Module

from utils import doublerelu

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
cuda = torch.cuda.is_available()
weight_decay = 10e-10
epochs = 1000
seed = 165

# %%
np.random.seed(seed)
torch.manual_seed(seed)
if cuda:
    torch.cuda.manual_seed(seed)

# %%
class GNN1Layer(Module):

    def __init__(self, batch_size, in_features, out_features):
        super(GNN1Layer, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.batch_size = batch_size

        weight1_eye = torch.FloatTensor(torch.eye(in_features, out_features))
        weight1_eye = weight1_eye.reshape((1, in_features, out_features))
        weight1_eye = weight1_eye.repeat(batch_size, 1, 1)
        self.weight1 = Parameter(weight1_eye)
        self.weight2 = Parameter(torch.zeros(batch_size, in_features, out_features))

    def forward(self, input, adj):
        v1 = torch.bmm(input, self.weight1)
        v2 = torch.bmm(torch.bmm(adj, input), self.weight2)
        output = v1 + v2
        return output

# %%
class GNN2Layer(Module):

    def __init__(self, batch_size, in_features, out_features):
        super(GNN2Layer, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.batch_size = batch_size
        weight1_eye = torch.FloatTensor(torch.eye(in_features, out_features))
        weight1_eye = weight1_eye.reshape((1, in_features, out_features))
        weight1_eye = weight1_eye.repeat(batch_size, 1, 1)
        weight1_rand = torch.empty(batch_size,in_features,out_features-in_features)
        torch.nn.init.xavier_uniform_(weight1_rand, gain=1.0)
        self.weight1 = Parameter(weight1_eye)
        self.weight2 = Parameter(torch.zeros(batch_size, in_features, out_features))

    def forward(self, input, adj):
        v1 = torch.bmm(input, self.weight1)
        v2 = torch.bmm(torch.bmm(adj, input), self.weight2)
        output = v1 + v2
        return output

# %%
class GNN1(nn.Module):

    def __init__(self, batch_size, nfeat, ndim, hidden):
        super(GNN1, self).__init__()

        self.gc1 = GNN1Layer(batch_size, ndim, ndim)

    def forward(self, x, adj):
        x = doublerelu(self.gc1(x, adj))
        x = x/x.sum(axis=2).unsqueeze(2) #normalize st sum = 1
        return x

# %%
class GNN2(nn.Module):

    def __init__(self, batch_size, nfeat, ndim, hidden):
        super(GNN2, self).__init__()

        self.gc1 = GNN2Layer(batch_size, ndim, hidden)
        self.gc2 = GNN1Layer(batch_size, hidden, ndim)

    def forward(self, x, adj):
        x = doublerelu(self.gc1(x, adj))
        x = doublerelu(self.gc2(x, adj))
        x = x/x.sum(axis=2).unsqueeze(2) #normalize st sum = 1
        return x

# %%
def community_detection(G,method,GNN,features=None,hidden=1):
    
    adj = nx.to_numpy_matrix(G)
    adj = np.expand_dims(adj, axis=0)
        
    #Combo
    combo_partition = pycombo.execute(G)
    nb_comm = max(combo_partition[0].values())+1
    combo_mod = combo_partition[1]

    adj_norm = normalize(adj)

    adj = torch.FloatTensor(np.array(adj))
    adj_norm = torch.FloatTensor(np.array(adj_norm))
    
        
    if type(features) == type(None):

        # features
        if method == "louvain":
            partition = community_louvain.best_partition(G)
            #get binary matrix of the partition
            nb_community = max(list(partition.values())) + 1
            communities =  np.array(list(partition.values())).reshape(-1)
            C = np.eye(nb_community)[communities]
            C = torch.FloatTensor(C)
            #perturbations
            C = perturb(C)
        elif method == "spectral":
            partition = spectralPartition(adj,nb_comm)
            C = partition.float()
            nb_community = C.shape[1]

        features = torch.FloatTensor(C)
        features = features.unsqueeze(0)
    
    nb_community = features.shape[-1]
    
    if method == "louvain":
        lr = 0.001
    elif method == "spectral":
        lr = 0.001
        

    Q = modularity_matrix(adj)
    
    # Model and optimizer

    model = GNN(batch_size=adj.shape[0],
                nfeat=adj.shape[1],
                ndim=nb_community,
                hidden=hidden)

    if cuda:
        model.cuda()
        features = features.cuda()
        adj = adj.cuda()
        adj_norm = adj_norm.cuda()
        Q = Q.cuda()

    # Train model
    t_total = time.time()

    optimizer = optim.Adam(model.parameters(),
                           lr=lr, weight_decay=weight_decay)
    
    
    for epoch in range(epochs):

        t = time.time()
        model.train()
        optimizer.zero_grad()

        C = model(features, adj_norm)
        loss = modularity(C,Q)

        loss.backward()

        optimizer.step()

        if epoch == 0:
            best_loss = loss
            init_mod = loss
            best_C = C
        else:
            if loss < best_loss:
                best_loss = loss
                best_C = C

        if epoch % 100 == 0:
            print('Epoch: {:04d}'.format(epoch + 1),
                  'Modularity: {:.8f}'.format(-best_loss.item()),
                  'time: {:.4f}s'.format(time.time() - t))

    print("Optimization Finished!")
    print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
    
    return nb_community,-init_mod,-best_loss,combo_mod, best_C

# %%
def perturb(A):
    p = 0.4
    epsilon = torch.rand(A.shape).uniform_(0, p) - torch.rand(A.shape).uniform_(0, p)
    return torch.clip(A + epsilon,0,1)

# %%
def spectralPartition(A,nb_comm):
    A = A[0] # TODO 3D
    clustering = SpectralClustering(n_clusters=nb_comm,assign_labels='discretize',random_state=0).fit(A)
    clusters = list(clustering.labels_)
    partitions = torch.tensor(clusters)
    return torch.nn.functional.one_hot(partitions)

# %%
G = [nx.karate_club_graph(),nx.les_miserables_graph(),nx.florentine_families_graph(),nx.house_graph()]
methods = ["louvain","spectral"]
nb_communities = []
init_mods = []
finetuned_mods = []
combo_mods = []
methodss = []
networks = ["Karate Club","Karate Club","Les Miserables","Les Miserables","Florentine","Florentine","House Graph","House Graph"]
for network in G:
    for method in methods:
        print(network,end=" ")
        print(method)
        nb_community,init_mod,finetuned_mod,combo_mod,features = community_detection(network,method,GNN1,hidden=1)
        nb_community,init_mod,finetuned_mod,combo_mod,features = community_detection(network,method,GNN2,features=features.detach(),hidden=nb_community+4)
        initial_mod = torch.clone(init_mod)
        while(init_mod<finetuned_mod):
            nb_community,init_mod,finetuned_mod,combo_mod,features = community_detection(network,method,GNN2,features=features.detach(),hidden=nb_community+4)
        nb_communities.append(nb_community)
        init_mods.append(initial_mod.cpu().detach().numpy()[0][0])
        finetuned_mods.append(finetuned_mod.cpu().detach().numpy()[0][0])
        combo_mods.append(combo_mod)
        methodss.append(method)
# Out:
# Zachary's Karate Club louvain
# Epoch: 0001 Modularity: 0.23050189 time: 0.3917s
# Epoch: 0101 Modularity: 0.38391131 time: 0.0125s
# Epoch: 0201 Modularity: 0.41260108 time: 0.0000s
# Epoch: 0301 Modularity: 0.41529948 time: 0.0000s
# Epoch: 0401 Modularity: 0.41559827 time: 0.0000s
# Epoch: 0501 Modularity: 0.41559827 time: 0.0000s
# Epoch: 0601 Modularity: 0.41559827 time: 0.0000s
# Epoch: 0701 Modularity: 0.41559827 time: 0.0000s
# Epoch: 0801 Modularity: 0.41559827 time: 0.0000s
# Epoch: 0901 Modularity: 0.41559827 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 1.9634s
# Epoch: 0001 Modularity: 0.41559827 time: 0.0125s
# Epoch: 0101 Modularity: 0.41559827 time: 0.0000s
# Epoch: 0201 Modularity: 0.41559827 time: 0.0000s
# Epoch: 0301 Modularity: 0.41559827 time: 0.0000s
# Epoch: 0401 Modularity: 0.41559827 time: 0.0000s
# Epoch: 0501 Modularity: 0.41559827 time: 0.0000s
# Epoch: 0601 Modularity: 0.41559827 time: 0.0110s
# Epoch: 0701 Modularity: 0.41559827 time: 0.0156s
# Epoch: 0801 Modularity: 0.41559827 time: 0.0000s
# Epoch: 0901 Modularity: 0.41559827 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 2.6178s
# Zachary's Karate Club spectral
# Epoch: 0001 Modularity: 0.34015450 time: 0.0000s
# Epoch: 0101 Modularity: 0.35217637 time: 0.0000s
# Epoch: 0201 Modularity: 0.35755002 time: 0.0000s
# Epoch: 0301 Modularity: 0.36043119 time: 0.0000s
# Epoch: 0401 Modularity: 0.36215097 time: 0.0000s
# Epoch: 0501 Modularity: 0.36325338 time: 0.0000s
# Epoch: 0601 Modularity: 0.36398935 time: 0.0156s
# Epoch: 0701 Modularity: 0.36450377 time: 0.0000s
# Epoch: 0801 Modularity: 0.36486542 time: 0.0000s
# Epoch: 0901 Modularity: 0.36512989 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 1.6783s
# Epoch: 0001 Modularity: 0.36532241 time: 0.0000s
# Epoch: 0101 Modularity: 0.39355159 time: 0.0000s
# Epoch: 0201 Modularity: 0.39907956 time: 0.0000s
# Epoch: 0301 Modularity: 0.39907956 time: 0.0000s
# Epoch: 0401 Modularity: 0.39907956 time: 0.0000s
# Epoch: 0501 Modularity: 0.39907956 time: 0.0000s
# Epoch: 0601 Modularity: 0.39907956 time: 0.0000s
# Epoch: 0701 Modularity: 0.39907956 time: 0.0000s
# Epoch: 0801 Modularity: 0.39907956 time: 0.0020s
# Epoch: 0901 Modularity: 0.39907956 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 2.3542s
# Epoch: 0001 Modularity: 0.39907956 time: 0.0156s
# Epoch: 0101 Modularity: 0.39907956 time: 0.0000s
# Epoch: 0201 Modularity: 0.39907956 time: 0.0156s
# Epoch: 0301 Modularity: 0.39907956 time: 0.0156s
# Epoch: 0401 Modularity: 0.39907956 time: 0.0000s
# Epoch: 0501 Modularity: 0.39907956 time: 0.0000s
# Epoch: 0601 Modularity: 0.39907956 time: 0.0000s
# Epoch: 0701 Modularity: 0.39907956 time: 0.0000s
# Epoch: 0801 Modularity: 0.39907956 time: 0.0020s
# Epoch: 0901 Modularity: 0.39907956 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 2.4009s
#  louvain
# Epoch: 0001 Modularity: 0.27782995 time: 0.0000s
# Epoch: 0101 Modularity: 0.52093709 time: 0.0000s
# Epoch: 0201 Modularity: 0.56288314 time: 0.0000s
# Epoch: 0301 Modularity: 0.56486779 time: 0.0000s
# Epoch: 0401 Modularity: 0.56507283 time: 0.0000s
# Epoch: 0501 Modularity: 0.56524521 time: 0.0000s
# Epoch: 0601 Modularity: 0.56526285 time: 0.0000s
# Epoch: 0701 Modularity: 0.56528378 time: 0.0000s
# Epoch: 0801 Modularity: 0.56530869 time: 0.0000s
# Epoch: 0901 Modularity: 0.56533885 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 1.5054s
# Epoch: 0001 Modularity: 0.56537563 time: 0.0000s
# Epoch: 0101 Modularity: 0.56540668 time: 0.0156s
# Epoch: 0201 Modularity: 0.56541568 time: 0.0000s
# Epoch: 0301 Modularity: 0.56541568 time: 0.0000s
# Epoch: 0401 Modularity: 0.56541568 time: 0.0000s
# Epoch: 0501 Modularity: 0.56541568 time: 0.0000s
# Epoch: 0601 Modularity: 0.56541568 time: 0.0156s
# Epoch: 0701 Modularity: 0.56541568 time: 0.0000s
# Epoch: 0801 Modularity: 0.56541568 time: 0.0000s
# Epoch: 0901 Modularity: 0.56541568 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 2.4337s
# Epoch: 0001 Modularity: 0.56541568 time: 0.0156s
# Epoch: 0101 Modularity: 0.56541568 time: 0.0000s
# Epoch: 0201 Modularity: 0.56541568 time: 0.0000s
# Epoch: 0301 Modularity: 0.56541568 time: 0.0000s
# Epoch: 0401 Modularity: 0.56541568 time: 0.0000s
# Epoch: 0501 Modularity: 0.56541568 time: 0.0000s
# Epoch: 0601 Modularity: 0.56541568 time: 0.0000s
# Epoch: 0701 Modularity: 0.56541568 time: 0.0000s
# Epoch: 0801 Modularity: 0.56541568 time: 0.0000s
# Epoch: 0901 Modularity: 0.56541568 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 2.6973s
#  spectral
# Epoch: 0001 Modularity: 0.11745612 time: 0.0000s
# Epoch: 0101 Modularity: 0.14271656 time: 0.0000s
# Epoch: 0201 Modularity: 0.17422183 time: 0.0000s
# Epoch: 0301 Modularity: 0.24213153 time: 0.0000s
# Epoch: 0401 Modularity: 0.39067581 time: 0.0000s
# Epoch: 0501 Modularity: 0.39067581 time: 0.0000s
# Epoch: 0601 Modularity: 0.39067581 time: 0.0000s
# Epoch: 0701 Modularity: 0.39067581 time: 0.0000s
# Epoch: 0801 Modularity: 0.39067581 time: 0.0000s
# Epoch: 0901 Modularity: 0.39067581 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 1.8517s
# Epoch: 0001 Modularity: 0.39067581 time: 0.0156s
# Epoch: 0101 Modularity: 0.42541081 time: 0.0156s
# Epoch: 0201 Modularity: 0.43547356 time: 0.0000s
# Epoch: 0301 Modularity: 0.45178562 time: 0.0000s
# Epoch: 0401 Modularity: 0.47372183 time: 0.0156s
# Epoch: 0501 Modularity: 0.47705168 time: 0.0000s
# Epoch: 0601 Modularity: 0.47705168 time: 0.0000s
# Epoch: 0701 Modularity: 0.47705168 time: 0.0000s
# Epoch: 0801 Modularity: 0.47705168 time: 0.0000s
# Epoch: 0901 Modularity: 0.47705168 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 3.5759s
# Epoch: 0001 Modularity: 0.47705168 time: 0.0156s
# Epoch: 0101 Modularity: 0.47850281 time: 0.0000s
# Epoch: 0201 Modularity: 0.47984880 time: 0.0000s
# Epoch: 0301 Modularity: 0.48034471 time: 0.0000s
# Epoch: 0401 Modularity: 0.48037615 time: 0.0156s
# Epoch: 0501 Modularity: 0.48039681 time: 0.0000s
# Epoch: 0601 Modularity: 0.48042908 time: 0.0000s
# Epoch: 0701 Modularity: 0.48045778 time: 0.0156s
# Epoch: 0801 Modularity: 0.48050460 time: 0.0000s
# Epoch: 0901 Modularity: 0.48055950 time: 0.0156s
# Optimization Finished!
# Total time elapsed: 4.0000s
# Epoch: 0001 Modularity: 0.48064023 time: 0.0145s
# Epoch: 0101 Modularity: 0.48080635 time: 0.0000s
# Epoch: 0201 Modularity: 0.48107138 time: 0.0000s
# Epoch: 0301 Modularity: 0.48155296 time: 0.0000s
# Epoch: 0401 Modularity: 0.48238045 time: 0.0100s
# Epoch: 0501 Modularity: 0.48340911 time: 0.0000s
# Epoch: 0601 Modularity: 0.48340911 time: 0.0000s
# Epoch: 0701 Modularity: 0.48340911 time: 0.0140s
# Epoch: 0801 Modularity: 0.48340911 time: 0.0000s
# Epoch: 0901 Modularity: 0.48340911 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 3.6713s
# Epoch: 0001 Modularity: 0.48340911 time: 0.0000s
# Epoch: 0101 Modularity: 0.48367625 time: 0.0000s
# Epoch: 0201 Modularity: 0.48387432 time: 0.0000s
# Epoch: 0301 Modularity: 0.48410803 time: 0.0000s
# Epoch: 0401 Modularity: 0.48430735 time: 0.0000s
# Epoch: 0501 Modularity: 0.48446167 time: 0.0156s
# Epoch: 0601 Modularity: 0.48465157 time: 0.0085s
# Epoch: 0701 Modularity: 0.48481536 time: 0.0000s
# Epoch: 0801 Modularity: 0.48481536 time: 0.0045s
# Epoch: 0901 Modularity: 0.48481536 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 3.2335s
# Epoch: 0001 Modularity: 0.48481536 time: 0.0156s
# Epoch: 0101 Modularity: 0.48486429 time: 0.0000s
# Epoch: 0201 Modularity: 0.48488450 time: 0.0000s
# Epoch: 0301 Modularity: 0.48490477 time: 0.0156s
# Epoch: 0401 Modularity: 0.48491818 time: 0.0156s
# Epoch: 0501 Modularity: 0.48491818 time: 0.0000s
# Epoch: 0601 Modularity: 0.48491818 time: 0.0000s
# Epoch: 0701 Modularity: 0.48491818 time: 0.0000s
# Epoch: 0801 Modularity: 0.48491818 time: 0.0000s
# Epoch: 0901 Modularity: 0.48491818 time: 0.0156s
# Optimization Finished!
# Total time elapsed: 3.7342s
# Epoch: 0001 Modularity: 0.48491818 time: 0.0156s
# Epoch: 0101 Modularity: 0.48491818 time: 0.0000s
# Epoch: 0201 Modularity: 0.48491818 time: 0.0156s
# Epoch: 0301 Modularity: 0.48491818 time: 0.0000s
# Epoch: 0401 Modularity: 0.48491818 time: 0.0000s
# Epoch: 0501 Modularity: 0.48491818 time: 0.0000s
# Epoch: 0601 Modularity: 0.48491818 time: 0.0000s
# Epoch: 0701 Modularity: 0.48491818 time: 0.0125s
# Epoch: 0801 Modularity: 0.48491818 time: 0.0000s
# Epoch: 0901 Modularity: 0.48491818 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 3.8293s
#  louvain
# Epoch: 0001 Modularity: 0.27217841 time: 0.0156s
# Epoch: 0101 Modularity: 0.35727596 time: 0.0156s
# Epoch: 0201 Modularity: 0.39439148 time: 0.0000s
# Epoch: 0301 Modularity: 0.39875001 time: 0.0000s
# Epoch: 0401 Modularity: 0.39875001 time: 0.0156s
# Epoch: 0501 Modularity: 0.39875001 time: 0.0000s
# Epoch: 0601 Modularity: 0.39875001 time: 0.0000s
# Epoch: 0701 Modularity: 0.39875001 time: 0.0000s
# Epoch: 0801 Modularity: 0.39875001 time: 0.0156s
# Epoch: 0901 Modularity: 0.39875001 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 2.4819s
# Epoch: 0001 Modularity: 0.39875001 time: 0.0000s
# Epoch: 0101 Modularity: 0.39875001 time: 0.0000s
# Epoch: 0201 Modularity: 0.39875001 time: 0.0000s
# Epoch: 0301 Modularity: 0.39875001 time: 0.0000s
# Epoch: 0401 Modularity: 0.39875001 time: 0.0000s
# Epoch: 0501 Modularity: 0.39875001 time: 0.0000s
# Epoch: 0601 Modularity: 0.39875001 time: 0.0000s
# Epoch: 0701 Modularity: 0.39875001 time: 0.0000s
# Epoch: 0801 Modularity: 0.39875001 time: 0.0156s
# Epoch: 0901 Modularity: 0.39875001 time: 0.0156s
# Optimization Finished!
# Total time elapsed: 3.7813s
#  spectral
# Epoch: 0001 Modularity: -0.17124999 time: 0.0000s
# Epoch: 0101 Modularity: -0.04895511 time: 0.0000s
# Epoch: 0201 Modularity: -0.00743159 time: 0.0000s
# Epoch: 0301 Modularity: 0.03663643 time: 0.0000s
# Epoch: 0401 Modularity: 0.13065979 time: 0.0000s
# Epoch: 0501 Modularity: 0.21579754 time: 0.0156s
# Epoch: 0601 Modularity: 0.22337393 time: 0.0000s
# Epoch: 0701 Modularity: 0.23165216 time: 0.0000s
# Epoch: 0801 Modularity: 0.25094739 time: 0.0000s
# Epoch: 0901 Modularity: 0.30000001 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 2.4958s
# Epoch: 0001 Modularity: 0.30000001 time: 0.0000s
# Epoch: 0101 Modularity: 0.30000001 time: 0.0000s
# Epoch: 0201 Modularity: 0.30000001 time: 0.0000s
# Epoch: 0301 Modularity: 0.30000001 time: 0.0156s
# Epoch: 0401 Modularity: 0.30000001 time: 0.0156s
# Epoch: 0501 Modularity: 0.30000001 time: 0.0000s
# Epoch: 0601 Modularity: 0.30000001 time: 0.0000s
# Epoch: 0701 Modularity: 0.30000001 time: 0.0157s
# Epoch: 0801 Modularity: 0.30000001 time: 0.0000s
# Epoch: 0901 Modularity: 0.30000001 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 3.7851s
# House Graph louvain
# Epoch: 0001 Modularity: 0.07895397 time: 0.0000s
# Epoch: 0101 Modularity: 0.10031652 time: 0.0000s
# Epoch: 0201 Modularity: 0.11111113 time: 0.0156s
# Epoch: 0301 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0401 Modularity: 0.11111113 time: 0.0150s
# Epoch: 0501 Modularity: 0.11111113 time: 0.0156s
# Epoch: 0601 Modularity: 0.11111113 time: 0.0156s
# Epoch: 0701 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0801 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0901 Modularity: 0.11111113 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 2.5221s
# Epoch: 0001 Modularity: 0.11111113 time: 0.0156s
# Epoch: 0101 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0201 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0301 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0401 Modularity: 0.11111113 time: 0.0156s
# Epoch: 0501 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0601 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0701 Modularity: 0.11111113 time: 0.0030s
# Epoch: 0801 Modularity: 0.11111113 time: 0.0156s
# Epoch: 0901 Modularity: 0.11111113 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 3.8435s
# House Graph spectral
# Epoch: 0001 Modularity: -0.34722221 time: 0.0000s
# Epoch: 0101 Modularity: -0.16972028 time: 0.0000s
# Epoch: 0201 Modularity: -0.09772807 time: 0.0000s
# Epoch: 0301 Modularity: -0.06128071 time: 0.0000s
# Epoch: 0401 Modularity: -0.04037052 time: 0.0156s
# Epoch: 0501 Modularity: -0.02743197 time: 0.0000s
# Epoch: 0601 Modularity: -0.01901780 time: 0.0000s
# Epoch: 0701 Modularity: -0.01335561 time: 0.0000s
# Epoch: 0801 Modularity: -0.00945296 time: 0.0000s
# Epoch: 0901 Modularity: -0.00671766 time: 0.0156s
# Optimization Finished!
# Total time elapsed: 2.5423s
# Epoch: 0001 Modularity: -0.00479504 time: 0.0055s
# Epoch: 0101 Modularity: -0.00132926 time: 0.0156s
# Epoch: 0201 Modularity: -0.00055396 time: 0.0156s
# Epoch: 0301 Modularity: -0.00027048 time: 0.0156s
# Epoch: 0401 Modularity: -0.00014357 time: 0.0000s
# Epoch: 0501 Modularity: -0.00008039 time: 0.0000s
# Epoch: 0601 Modularity: -0.00004678 time: 0.0000s
# Epoch: 0701 Modularity: -0.00002805 time: 0.0000s
# Epoch: 0801 Modularity: -0.00001721 time: 0.0000s
# Epoch: 0901 Modularity: -0.00001077 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 3.7962s
# Epoch: 0001 Modularity: -0.00000686 time: 0.0000s
# Epoch: 0101 Modularity: -0.00000196 time: 0.0000s
# Epoch: 0201 Modularity: 0.00000034 time: 0.0156s
# Epoch: 0301 Modularity: 0.00000096 time: 0.0000s
# Epoch: 0401 Modularity: 0.00000111 time: 0.0000s
# Epoch: 0501 Modularity: 0.00000123 time: 0.0000s
# Epoch: 0601 Modularity: 0.00000140 time: 0.0156s
# Epoch: 0701 Modularity: 0.00000156 time: 0.0156s
# Epoch: 0801 Modularity: 0.00000174 time: 0.0000s
# Epoch: 0901 Modularity: 0.00000195 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 3.8770s
# Epoch: 0001 Modularity: 0.00000219 time: 0.0000s
# Epoch: 0101 Modularity: 0.00004022 time: 0.0000s
# Epoch: 0201 Modularity: 0.00107165 time: 0.0156s
# Epoch: 0301 Modularity: 0.00162701 time: 0.0000s
# Epoch: 0401 Modularity: 0.00255047 time: 0.0060s
# Epoch: 0501 Modularity: 0.00453471 time: 0.0186s
# Epoch: 0601 Modularity: 0.00677652 time: 0.0000s
# Epoch: 0701 Modularity: 0.00677652 time: 0.0000s
# Epoch: 0801 Modularity: 0.00677652 time: 0.0000s
# Epoch: 0901 Modularity: 0.00677652 time: 0.0156s
# Optimization Finished!
# Total time elapsed: 3.8918s
# Epoch: 0001 Modularity: 0.00677652 time: 0.0000s
# Epoch: 0101 Modularity: 0.03229629 time: 0.0000s
# Epoch: 0201 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0301 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0401 Modularity: 0.11111113 time: 0.0156s
# Epoch: 0501 Modularity: 0.11111113 time: 0.0140s
# Epoch: 0601 Modularity: 0.11111113 time: 0.0105s
# Epoch: 0701 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0801 Modularity: 0.11111113 time: 0.0156s
# Epoch: 0901 Modularity: 0.11111113 time: 0.0156s
# Optimization Finished!
# Total time elapsed: 3.8751s
# Epoch: 0001 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0101 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0201 Modularity: 0.11111113 time: 0.0156s
# Epoch: 0301 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0401 Modularity: 0.11111113 time: 0.0065s
# Epoch: 0501 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0601 Modularity: 0.11111113 time: 0.0156s
# Epoch: 0701 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0801 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0901 Modularity: 0.11111113 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 3.8740s

# %%
df = pd.DataFrame([networks,methodss,nb_communities,init_mods,finetuned_mods,combo_mods]).transpose()

# %%
df.columns = ["Network","Method","Communities","Initial Modularity","Finetuned Moduclarity","Combo Modularity"]

# %%
df
# Out:
#           Network    Method Communities Initial Modularity  \
# 0     Karate Club   louvain           4           0.415598
# 1     Karate Club  spectral           4           0.365322
# 2  Les Miserables   louvain           6           0.565376
# 3  Les Miserables  spectral           6           0.390676
# 4      Florentine   louvain           3           0.398750
# 5      Florentine  spectral           3           0.300000
# 6     House Graph   louvain           2           0.111111
# 7     House Graph  spectral           2          -0.004795
#
#   Finetuned Moduclarity Combo Modularity
# 0              0.415598         0.419790
# 1              0.399080         0.419790
# 2              0.565416         0.566688
# 3              0.484918         0.566688
# 4              0.398750         0.398750
# 5              0.300000         0.398750
# 6              0.111111         0.111111
# 7              0.111111         0.111111
